# %% [markdown]
# Data standarisation

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
from pyspark.sql.functions import lit, current_date,lower

# %%
from pyspark.sql.functions import col
cust_dl= "id int,lname string,fname string,age int,job string"
cust_df = spark.read.csv('/Volumes/izwe48catalog/we48db/staging/cust_prof_test.csv', schema=cust_dl)
#new column 
#cust_df1 = cust_df.withColumn("new job",col("job"))
#create a new column with the value 'APAC         
#cust_df1 = cust_df.withColumn("source",lit("APAC"))
#create date with current date
cust_df1 = cust_df1.withColumn("date",current_date())
#cust_df.printSchema()
cust_df.show(4)
cust_df1.show(4)
#Here are the DataFrames in the session
