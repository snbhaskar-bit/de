# %% [markdown]
# Write Spark data

# %%
#cust_df = spark.read.csv("dbfs:/Volumes/izwe48catalog/we48db/testvolume/custs", header=False, inferSchema=True)
scheme_str = "Cust_id int, fname string, lname string, age int, job string"
cust_df = spark.read.csv("dbfs:/Volumes/izwe48catalog/we48db/testvolume/custs", header=True)
cust_df.show()
cust_df.printSchema() 
cust_df.write.mode("overwrite").csv("dbfs:/Volumes/izwe48catalog/we48db/testvolume/custs_out", mode="overwrite", header=True)

# %% [markdown]
# Write in atable

# %%
scheme_str = "Cust_id int, fname string, lname string, age int, job string"
cust_df = spark.read.csv("dbfs:/Volumes/izwe48catalog/we48db/testvolume/custs", header=True,schema=scheme_str)
cust_df.show()
cust_df.printSchema()
cust_df.write.saveAsTable("izwe48catalog.we48db.table_customer")

# %%
# %sql
select * from izwe48catalog.we48db.table_customer

# %%
#sql based read

sql_cust_df=spark.sql("select * from izwe48catalog.we48db.table_customer limit 10")
sql_cust_df.show()

# %% [markdown]
# Read from a table
