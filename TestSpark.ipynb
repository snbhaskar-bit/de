# %%
print("Hello")

# %%
# %sql
create catalog if not exists izwe48catalog;
create schema if not exists izwe48catalog.we48db;
create volume if not exists izwe48catalog.we48db.testvolume;

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
cust_df = spark.read.csv("dbfs:/Volumes/izwe48catalog/we48db/testvolume/custs", header=False, inferSchema=True)
cust_df.show(20)
cust_df.printSchema()
cust_df.count()
cust_df.columns
cust_df.describe().show()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
scheme_str = "Cust_id int, fname string, lname string, age int, job string"
cust_df1 = spark.read.csv("dbfs:/Volumes/izwe48catalog/we48db/testvolume/custs", header=True,schema=scheme_str)
cust_df.spark.write.xml("dbfs:/Volumes/izwe48catalog/we48db/testvolume/custs_xml", mode="overwrite", rowTag="Cust_id")

# %%
data=[(500,"guru",22),(501,"satish",50)]
emp=[
  {
    "id": 1,
    "name": "Alice Johnson",
    "age": 28
  },
  {
    "id": 2,
    "name": "Bob Smith",
    "age": 34
  },
  {
    "id": 3,
    "name": "Charlie Brown",
    "age": 22
  }
]
emp_csv_df=spark.createDataFrame(data,["id","name","age"])
emp_csv_df.show()
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
# Define the schema for the JSON data
dd1_str = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True)
])
 
#emp_df=spark.read.json("/Volumes/izwe48catalog/we48db/staging/emp.json",schema=dd1_str)
emp_json_df=spark.createDataFrame(emp).toDF("id","name","age")
emp_json_df.show()
combined_emp_df=emp_csv_df.union(emp_json_df)
combined_emp_df.show()

# %% [markdown]
# Null Management

# %%
data=[(500,"guru",22),(501,"satish",50),(501,"allen",)]
emp_csv_df=spark.createDataFrame(data,["id","name","age"])
emp_csv_df.na.drop(subset=["name"]).show()
